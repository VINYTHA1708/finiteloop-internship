# %%
# Clean a dataset: fill missing values, drop duplicates, convert types using Pandas.

import pandas as pd

df = pd.read_csv("Mall_Customers.csv")

print("Before Cleaning, No.of missing values:")
print(df.isnull().sum())
# Out:
# Before Cleaning, No.of missing values:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include = 'number').columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
object_cols = df.select_dtypes(include = 'object').columns
for col in object_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df = df.drop_duplicates()

# %%
df["Age"] = df["Age"].astype(int)
df["Annual Income (k$)"] = df["Annual Income (k$)"].astype(float)

# %%
print("Cleaned Dataset Info")
df.info()
# Out:
# Cleaned Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    float64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 7.9+ KB
