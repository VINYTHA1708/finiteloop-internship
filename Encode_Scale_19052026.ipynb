# %%
# Encode categorical data with Pandas’ get_dummies and scale features using scikit-learn.

import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("Mall_Customers.csv")

print("Before Encoding:")
print(df.head())
# Out:
# Before Encoding:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df_encoded = pd.get_dummies(df, columns = ['Genre'])

print("After Encoding:")
print(df_encoded.head())
# Out:
# After Encoding:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Female  \
# 0           1   19                  15                      39         False
# 1           2   21                  15                      81         False
# 2           3   20                  16                       6          True
# 3           4   23                  16                      77          True
# 4           5   31                  17                      40          True
#
#    Genre_Male
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False

# %%
features = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
scaler = StandardScaler()

df_encoded[features] = scaler.fit_transform(df_encoded[features])

print("After Scaling:")
print(df_encoded.head())
# Out:
# After Scaling:
#    CustomerID       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1 -1.424569           -1.738999               -0.434801
# 1           2 -1.281035           -1.738999                1.195704
# 2           3 -1.352802           -1.700830               -1.715913
# 3           4 -1.137502           -1.700830                1.040418
# 4           5 -0.563369           -1.662660               -0.395980
#
#    Genre_Female  Genre_Male
# 0         False        True
# 1         False        True
# 2          True       False
# 3          True       False
# 4          True       False
